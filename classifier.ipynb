# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# Load the dataset
file = open('data/data.27239_poisson_page1_processed.json')
df = pd.read_json(file)

# %%
# Select the columns we consider as pertinent. 
# This is an arbitrary selection based on intuition.
data = df[[ 'date_operation', 'libelle_qualification_operation', 'etat_avancement_operation', 
           'code_station', 'code_point_prelevement', 'coordonnee_x_station', 'coordonnee_y_station', 
           'code_entite_hydro', 'libelle_entite_hydro', 'libelle_commune', 'code_commune',
           'libelle_bassin', 'code_bassin', 'code_lot', 'code_type_lot', 'libelle_type_lot',
           'effectif_lot', 'nom_commun_taxon', 'type_longueur_lot', 'taille_individu', 
           'importances_pathologies_individu']]

data.head()
# Out:
#          date_operation libelle_qualification_operation  \
# 0  2020-09-15T09:00:00Z                        Correcte
# 1  2020-09-15T09:00:00Z                        Correcte
# 2  2020-09-15T09:00:00Z                        Correcte
# 3  2020-09-15T09:00:00Z                        Correcte
# 4  2020-09-15T09:00:00Z                        Correcte
#
#   etat_avancement_operation  code_station  code_point_prelevement  \
# 0           Validé niveau 2       3223200                       5
# 1           Validé niveau 2       3223200                       5
# 2           Validé niveau 2       3223200                       5
# 3           Validé niveau 2       3223200                       5
# 4           Validé niveau 2       3223200                       5
#
#    coordonnee_x_station  coordonnee_y_station code_entite_hydro  \
# 0                521063               6882342          H61-0400
# 1                521063               6882342          H61-0400
# ...
